# %%
#command line arguments to install follwing dependencies 
# !brew install cmake 
# !pip install dlib 
# !pip install face_recognition
# !pip install playsound
# Out:
# /bin/bash: brew: command not found
# Requirement already satisfied: dlib in /usr/local/lib/python3.7/dist-packages (19.18.0)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 22 kB/s
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=42e85ac52976b674aa56eb61442722fbefd914855ccf6138986bc607be4244b0
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py) ... done
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7037 sha256=281c493eeb7b02ea693ef7c7b24337c2d78ef13c687dab74b62a6023ead2c286
#   Stored in directory: /root/.cache/pip/wheels/ba/f8/bb/ea57c0146b664dca3a0ada4199b0ecb5f9dfcb7b7e22b65ba2
# Successfully built playsound
# Installing collected packages: playsound
# Successfully installed playsound-1.3.0

# %%
#upload the archived closed data folder to google colab and unzip it.
# !unzip  /content/dataset_B_FacialImages_highResolution.zip -d /content/closed_eye
# Out:
# unzip:  cannot find or open /content/dataset_B_FacialImages_highResolution.zip, /content/dataset_B_FacialImages_highResolution.zip.zip or /content/dataset_B_FacialImages_highResolution.zip.ZIP.

# %%
#upload the archived open data folder to google colab and unzip it.
# !unzip  /content/open_eye.zip -d /content/open_eye_
# Out:
# unzip:  cannot find or open /content/open_eye.zip, /content/open_eye.zip.zip or /content/open_eye.zip.ZIP.

# %%
from PIL import Image, ImageDraw
import face_recognition
import os
def crop_open_eye(open_eye_dataset):
    #Declaring count variable to know the number of proccesed images.
    count = 0

    # Open eye data has many folder,so we need to iterate them.
    for person in os.listdir(open_eye_dataset):
    # Each folder has a name assoicated with it and Each folder has many images.SO we need to iterate through every subfolder.
        for img_file in os.listdir(open_eye_dataset + '/' + person):
            # Open the file using Image library/.
            im=Image.open(open_eye_dataset + '/' + person+'/'+img_file)
            # Apply facical recognition to the image file.
            open_eye_face = face_recognition.load_image_file(open_eye_dataset + '/' + person + '/' + img_file)
            # Facial cordinates are stored in the list.
            face_cordinates = face_recognition.face_landmarks(open_eye_face)
          
            # Eyes will be recongzied and stored in the below list.
            EYES = []
            try:
              # append left eye and right eye to the above list.
                EYES.append(face_cordinates[0]['left_eye'])
                EYES.append(face_cordinates[0]['right_eye'])
            except:
                continue
            # Maximum and Mininum are found for each eye.
            for eye in EYES:
                max_x = max([coordinate[0] for coordinate in eye])
                min_x = min([coordinate[0] for coordinate in eye])
                max_y = max([coordinate[1] for coordinate in eye])
                min_y = min([coordinate[1] for coordinate in eye])
              # Finally x and y ranges are found.    
                xrange = -(min_x-max_x)
                yrange = -(min_y-max_y)
              
                
                if xrange > yrange:
                    #Four boundaries are set to crop out the eye image from the face.
                    right_boundary = round(.5*xrange-5+5) + max_x
                    left_boudnary = min_x - round(.5*xrange-5+5)
                    bottom_boundary = round(((right_boundary-left_boudnary) - yrange-5+5))/2 + max_y
                    top_boundary = min_y - round(((right_boundary-left_boudnary) - yrange+8-8))/2
                else:
                    #Four boundaries are set to crop out the eye image from the face.
                    bottom_boundary = round(.5*range_of_y) + max_y
                    top_boundary = min_y - round(.5*range_of_y)
                    right_boundary = round(((bottom_boundary-top_boundary) - xrange))/2 + max_x
                    left_boudnary = min_x - round(((bottom_boundary-top_boundary) - yrange))/2
              
                #Using above the ranges ,lets crop the eye from the face
                im = Image.open(open_eye_dataset + '/' + person + '/' + img_file)
                im = im.crop((left_boudnary, top_boundary, right_boundary, bottom_boundary))
                
                # Resize image to a uniform size to sent into a model.
                im = im.resize((80,80))
                # Create a name for the folder to which the cropped image to be stored
                name = '/content/preprocessed_open_eye/' + str(count) + '.jpg'
                # save the image in a jpeg format.
                im.save(name, 'JPEG')
                count += 1

# %%
# imports:
from PIL import Image, ImageDraw
import face_recognition
import os
def closed_function_to_crop_eyes_crop_eyes(closed_eye):
    # Establish count for iterative file saving
    count = 0

    # For loop going through each image file
    for person in os.listdir(closed_eye):
        for img_file in os.listdir(closed_eye + '/' + person):
            # Open the file using Image library/.
            im=Image.open(closed_eye + '/' + person+'/'+img_file)
            # Apply facical recognition to the image file.
            open_eye_face = face_recognition.load_image_file(closed_eye + '/' + person + '/' + img_file)
            # Facial cordinates are stored in the list.
            face_cordinates = face_recognition.face_landmarks(open_eye_face)
          
            # Eyes will be recongzied and stored in the below list.
            EYES = []
            try:
              # append left eye and right eye to the above list.
                EYES.append(face_cordinates[0]['left_eye'])
                EYES.append(face_cordinates[0]['right_eye'])
            except:
                continue
            # Maximum and Mininum are found for each eye.
            for eye in EYES:
                max_x = max([coordinate[0] for coordinate in eye])
                min_x = min([coordinate[0] for coordinate in eye])
                max_y = max([coordinate[1] for coordinate in eye])
                min_y = min([coordinate[1] for coordinate in eye])
              # Finally x and y ranges are found.    
                xrange = -(min_x-max_x)
                yrange = -(min_y-max_y)
              
                
                if xrange > yrange:
                    #Four boundaries are set to crop out the eye image from the face.
                    right_boundary = round(.5*xrange-5+5) + max_x
                    left_boudnary = min_x - round(.5*xrange-5+5)
                    bottom_boundary = round(((right_boundary-left_boudnary) - yrange-5+5))/2 + max_y
                    top_boundary = min_y - round(((right_boundary-left_boudnary) - yrange+8-8))/2
                else:
                    #Four boundaries are set to crop out the eye image from the face.
                    bottom_boundary = round(.5*range_of_y) + max_y
                    top_boundary = min_y - round(.5*range_of_y)
                    right_boundary = round(((bottom_boundary-top_boundary) - xrange))/2 + max_x
                    left_boudnary = min_x - round(((bottom_boundary-top_boundary) - yrange))/2
              
                #Using above the ranges ,lets crop the eye from the face
                im = Image.open(closed_eye + '/' + person + '/' + img_file)
                im = im.crop((left_boudnary, top_boundary, right_boundary, bottom_boundary))
                
                # Resize image to a uniform size to sent into a model.
                im = im.resize((80,80))
                # Create a name for the folder to which the cropped image to be stored
                name = '/content/preprocessed_closed_eye/' + str(count) + '.jpg'
                # save the image in a jpeg format.
                im.save(name, 'JPEG')
                count += 1
                # print count every 200 photos to monitor progress
                if count<100:
                  pass
                else:
                  break

# %%
#Preproccesing Data

crop_open_eye('open_eye_')     
closed_function_to_crop_eyes('closed_eye')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-181b01ec4830> in <module>()
#       1 #Preproccesing Data
#       2
# ----> 3 crop_open_eye('open_eye_')
#       4 closed_function_to_crop_eyes('closed_eye')
#
# <ipython-input-4-3ca2472094c1> in crop_open_eye(open_eye_dataset)
#       8
#       9     # Open eye data has many folder,so we need to iterate them.
# ---> 10     for person in os.listdir(open_eye_dataset):
#      11     # Each folder has a name assoicated with it and Each folder has many images.SO we need to iterate through every subfolder.
#      12         for img_file in os.listdir(open_eye_dataset + '/' + person):
#
# FileNotFoundError: [Errno 2] No such file or directory: 
jpg
#   inflating: preprocessed_closed_eye/content/preprocessed_closed_eye/941.jpg
#   inflating: preprocessed_closed_eye/content/preprocessed_closed_eye/833.jpg
# Archive:  /content/preprocessed_open_eye.zip
#    creating: preprocessed_open_eye/content/preprocessed_open_eye/
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/49.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/78.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/6.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/42.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/32.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/43.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/76.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/72.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/0.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/77.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/9.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/58.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/74.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/30.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/1.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/51.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/24.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/86.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/21.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/66.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/89.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/61.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/55.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/93.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/83.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/46.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/14.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/88.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/87.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/60.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/80.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/95.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/73.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/27.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/18.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/63.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/64.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/35.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/50.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/68.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/65.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/91.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/7.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/57.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/28.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/52.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/41.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/8.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/34.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/99.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/79.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/25.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/22.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/98.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/17.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/10.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/20.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/62.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/4.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/85.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/53.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/13.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/69.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/67.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/33.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/31.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/84.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/29.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/96.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/92.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/71.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/81.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/40.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/36.jpg
#  extracting: preprocessed_open_eye/content/preprocessed_open_eye/.zip
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/37.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/56.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/47.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/16.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/97.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/59.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/54.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/15.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/38.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/19.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/94.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/2.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/82.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/70.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/3.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/26.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/5.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/23.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/90.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/11.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/12.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/48.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/75.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/45.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/44.jpg
#   inflating: preprocessed_open_eye/content/preprocessed_open_eye/39.jpg

# %% [markdown]
# **PHASE 3**
#
# 2. For each image in the folder convert them into equalivalent pixel level data which has a size of 80*80 .

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)

# %%
import os
from PIL import Image, ImageDraw
import face_recognition
import os
import cv2 as c_v

def loading_images(folder, eyes = 0):

    images = []
    for filename in os.listdir(folder):
        try:
            img = c_v.imread(os.path.join(folder,filename))
            #image resizing 
            img = c_v.resize(img, (80,80)) 
            images.append([img, eyes])
        except:
            continue
        

    return images

#Retreving images from eyes open dataset. and converting it into a list
open_eyes = loading_images("/content/preprocessed_closed_eye/content/preprocessed_closed_eye", 0)
#Retreving images from eyes closed dataset. and converting it into a list
closed_eyes = loading_images("/content/preprocessed_open_eye/content/preprocessed_open_eye", 1)
eyes = closed_eyes + open_eyes

# %% [markdown]
# **Phase 3**
#
#
# 3.Spliting the whole data into X_train,X_test,y_train,y_test using treain_test_spilt with a ration of 70 /30

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X = [] 
y = [] 
for features, label in eyes: 
     X.append(features)
     y.append(label)
X = (np.array(X).reshape(-1, 80, 80, 3))/255.0
y = np.array(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y,test_size=0.3)

# %% [markdown]
# **Phase 4**

# %%
# Instantiate the model
from keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
import tensorflow as tf




#plain stack of layers where each layer has exactly one input tensor and one output tensor.
model = Sequential()
#first three convolutional layers
model.add(Conv2D(
                filters = 32, # number of filters
                kernel_size = (3,3), # height/width of filter
                activation = 'relu', # activation function 
                input_shape = (80,80,3) # shape of input (image)
                ))
model.add(Conv2D(
                filters = 32, # number of filters
                kernel_size = (3,3), # height/width of filter
                activation = 'relu' # activation function 
                ))
model.add(Conv2D(
                filters = 32, # number of filters
                kernel_size = (3,3), # height/width of filter
                activation = 'relu' # activation function 
                ))

# Adding pooling after convolutional layers
#Downsamples the input along its spatial dimensions (height and width) by taking the maximum value 
model.add(MaxPooling2D(pool_size = (2,2))) # Dimensions of the region that you are pooling

# Adding second set of convolutional layers
#Conv2D layers are generally used for achieving high accuracy in image recognition tasks
model.add(Conv2D(
                filters = 32, # number of filters
                kernel_size = (3,3), # height/width of filter
                activation = 'relu' # activation function 
                ))
model.add(Conv2D(
                filters = 32, # number of filters
                kernel_size = (3,3), # height/width of filter
                activation = 'relu' # activation function 
                ))
# Adding second set of convolutional layers
model.add(Conv2D(
                filters = 32, # number of filters
                kernel_size = (3,3), # height/width of filter
                activation = 'relu' # activation function 
                ))
model.add(Conv2D(
                filters = 32, # number of filters
                kernel_size = (3,3), # height/width of filter
                activation = 'relu' # activation function 
                ))

# Add last pooling layer.
model.add(MaxPooling2D(pool_size=(2,2)))
# get a copy of an given array collapsed into one dimension.
model.add(Flatten())

# Adding first dense layer with 256 nodes
model.add(Dense(256, activation='relu'))

# Adding a dropout layer to avoid overfitting
model.add(Dropout(0.3))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3)) 

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))

# adding output layer
model.add(Dense(1, activation = 'sigmoid'))

# compiling the model
#binary_crossentropy: It can also be used to describe a predicted outcome compare to the true outcome
#adam: Adaptive Moment Estimation is an algorithm for optimization technique for gradient descent
#AUC: The Area Under the Curve (AUC) is the measure of the ability of a classifier to distinguish between classes 
model.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=[tf.keras.metrics.AUC(curve = 'PR')])

# %% [markdown]
# **Training the model with a batch size 500 and epochs = 30**

# %%
# fitting the model
history=model.fit(X_train,
            y_train,
            batch_size=500,
            validation_data=(X_test, y_test),
            epochs=30)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 24s 4s/step - loss: 0.5384 - auc: 0.0495 - val_loss: 0.1718 - val_auc: 0.1257
# Epoch 2/30
# 3/3 [==============================] - 2s 617ms/step - loss: 0.2586 - auc: 0.0878 - val_loss: 0.2012 - val_auc: 0.1290
# Epoch 3/30
# 3/3 [==============================] - 2s 616ms/step - loss: 0.2142 - auc: 0.0591 - val_loss: 0.2204 - val_auc: 0.1314
# Epoch 4/30
# 3/3 [==============================] - 2s 615ms/step - loss: 0.2263 - auc: 0.0576 - val_loss: 0.1677 - val_auc: 0.1286
# Epoch 5/30
# 3/3 [==============================] - 2s 617ms/step - loss: 0.1870 - auc: 0.0899 - val_loss: 0.1763 - val_auc: 0.1325
# Epoch 6/30
# 3/3 [==============================] - 2s 625ms/step - loss: 0.2027 - auc: 0.0606 - val_loss: 0.1694 - val_auc: 0.1397
# Epoch 7/30
# 3/3 [==============================] - 2s 625ms/step - loss: 0.1906 - auc: 0.0720 - val_loss: 0.1742 - val_auc: 0.1424
# Epoch 8/30
# 3/3 [==============================] - 2s 616ms/step - loss: 0.1810 - auc: 0.0938 - val_loss: 0.1647 - val_auc: 0.1435
# Epoch 9/30
# 3/3 [==============================] - 2s 622ms/step - loss: 0.1864 - auc: 0.0772 - val_loss: 0.1644 - val_auc: 0.1461
# Epoch 10/30
# 3/3 [==============================] - 2s 618ms/step - loss: 0.1773 - auc: 0.0907 - val_loss: 0.1655 - val_auc: 0.1533
# Epoch 11/30
# 3/3 [==============================] - 2s 624ms/step - loss: 0.1789 - auc: 0.1059 - val_loss: 0.1648 - val_auc: 0.1599
# Epoch 12/30
# 3/3 [==============================] - 2s 612ms/step - loss: 0.1824 - auc: 0.0847 - val_loss: 0.1611 - val_auc: 0.1694
# Epoch 13/30
# 3/3 [==============================] - 2s 622ms/step - loss: 0.1802 - auc: 0.0857 - val_loss: 0.1632 - val_auc: 0.1759
# Epoch 14/30
# 3/3 [==============================] - 2s 618ms/step - loss: 0.1727 - auc: 0.1293 - val_loss: 0.1577 - val_auc: 0.1952
# Epoch 15/30
# 3/3 [==============================] - 2s 622ms/step - loss: 0.1757 - auc: 0.1185 - val_loss: 0.1553 - val_auc: 0.1950
# Epoch 16/30
# 3/3 [==============================] - 2s 624ms/step - loss: 0.1749 - auc: 0.1096 - val_loss: 0.1545 - val_auc: 0.2229
# Epoch 17/30
# 3/3 [==============================] - 2s 615ms/step - loss: 0.1719 - auc: 0.1086 - val_loss: 0.1474 - val_auc: 0.2570
# Epoch 18/30
# 3/3 [==============================] - 2s 624ms/step - loss: 0.1602 - auc: 0.1514 - val_loss: 0.1452 - val_auc: 0.3099
# Epoch 19/30
# 3/3 [==============================] - 2s 621ms/step - loss: 0.1549 - auc: 0.2050 - val_loss: 0.1378 - val_auc: 0.3187
# Epoch 20/30
# 3/3 [==============================] - 2s 632ms/step - loss: 0.1583 - auc: 0.2090 - val_loss: 0.1355 - val_auc: 0.4193
# Epoch 21/30
# 3/3 [==============================] - 2s 615ms/step - loss: 0.1486 - auc: 0.2925 - val_loss: 0.1245 - val_auc: 0.5102
# Epoch 22/30
# 3/3 [==============================] - 2s 624ms/step - loss: 0.1388 - auc: 0.3650 - val_loss: 0.1182 - val_auc: 0.6768
# Epoch 23/30
# 3/3 [==============================] - 2s 622ms/step - loss: 0.1200 - auc: 0.5285 - val_loss: 0.0967 - val_auc: 0.8024
# Epoch 24/30
# 3/3 [==============================] - 2s 621ms/step - loss: 0.1003 - auc: 0.7427 - val_loss: 0.0879 - val_auc: 0.8681
# Epoch 25/30
# 3/3 [==============================] - 2s 624ms/step - loss: 0.0860 - auc: 0.8352 - val_loss: 0.0952 - val_auc: 0.8268
# Epoch 26/30
# 3/3 [==============================] - 2s 607ms/step - loss: 0.0849 - auc: 0.8330 - val_loss: 0.0701 - val_auc: 0.8736
# Epoch 27/30
# 3/3 [==============================] - 2s 624ms/step - loss: 0.0754 - auc: 0.8608 - val_loss: 0.0687 - val_auc: 0.8756
# Epoch 28/30
# 3/3 [==============================] - 2s 614ms/step - loss: 0.0680 - auc: 0.8973 - val_loss: 0.0705 - val_auc: 0.8649
# Epoch 29/30
# 3/3 [==============================] - 2s 616ms/step - loss: 0.0658 - auc: 0.9092 - val_loss: 0.0646 - val_auc: 0.8809
# Epoch 30/30
# 3/3 [==============================] - 2s 612ms/step - loss: 0.0616 - auc: 0.8808 - val_loss: 0.0732 - val_auc: 0.8823

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# `**Validation AUC SCORE  = [0.9123 , 0.0431 ]**`

# %%
# evaluate the model 
model.evaluate(X_test, y_test, verbose=1)
# Out:
# 20/20 [==============================] - 1s 31ms/step - loss: 0.0500 - auc: 0.8487
# [0.05003877729177475, 0.8487206697463989]

# %% [markdown]
# **Test AUC SCORE  = [0.8487206697463989 , 0.05003877729177475 ]**

# %% [markdown]
# **Final Phase**

# %%
import cv2
import numpy as np
from playsound import playsound
from PIL import Image, ImageDraw
import face_recognition
from tensorflow import keras
eye_model = keras.models.load_model('/content/cnnCat2.h5')

# webcam frame is inputted into function
def eye_cropper(frame):

    # create a variable for the facial feature coordinates
    facial_features_list = face_recognition.face_landmarks(frame)

    # create a placeholder list for the eye coordinates
    # and append coordinates for eyes to list unless eyes
    # weren't found by facial recognition
    try:
        eye = facial_features_list[0]['left_eye']
    except:
        try:
            eye = facial_features_list[0]['right_eye']
        except:
            return
    
    # establish the max x and y coordinates of the eye
    maximum_x = max([coordinate[0] for coordinate in eye])
    mininum_x = min([coordinate[0] for coordinate in eye])
    maximum_y = max([coordinate[1] for coordinate in eye])
    mininum_y = min([coordinate[1] for coordinate in eye])

    # establish the range of x and y coordinates
    range_of_x = maximum_x - mininum_x
    range_of_y = maximum_y - mininum_y

    # in order to make sure the full eye is captured,
    # calculate the coordinates of a square that has a
    # 50% cushion added to the axis with a larger range and
    # then match the smaller range to the cushioned larger range
    if range_of_x > range_of_y:
        right = round(.5*range_of_x) + maximum_x
        left = mininum_x - round(.5*range_of_x)
        bottom = round((((right-left) - range_of_y))/2) + maximum_y
        top = mininum_y - round((((right-left) - range_of_y))/2)
    else:
        bottom = round(.5*range_of_y) + maximum_y
        top = mininum_y - round(.5*range_of_y)
        right = round((((bottom-top) - range_of_x))/2) + maximum_x
        left = mininum_x - round((((bottom-top) - range_of_x))/2)

    # crop the image according to the coordinates determined above
    cropped = frame[top:(bottom + 1), left:(right + 1)]

    # resize the image
    cropped = cv2.resize(cropped, (80,80))
    predicted_image = cropped.reshape(-1, 80, 80, 3)

    return predicted_image

# initiate webcam
cap = cv2.VideoCapture(0)
w = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
h = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
if not cap.isOpened():
    raise IOError('Cannot open webcam')

# set a counter
counter = 0

# create a while loop that runs while webcam is in use
while True:

    # capture frames being outputted by webcam
    ret, frame = cap.read()

    # use only every other frame to manage speed and memory usage
    count_of_frame = 0
    if count_of_frame == 0:
        count_of_frame += 1
        pass
    else:
        count = 0
        continue

    # function called on the frame
    predicted_image = eye_cropper(frame)
    try:
        predicted_image = predicted_image/255.0
    except:
        continue

    # get prediction from model
    prediction = eye_model.predict(predicted_image)

    # Based on prediction, display either "Open Eyes" or "Closed Eyes"
    if prediction < 0.5:
        counter = 0
        status = 'Open'

        cv2.rectangle(frame, (round(w/2) - 110,20), (round(w/2) + 110, 80), (38,38,38), -1)

        cv2.putText(frame, status, (round(w/2)-80,70), cv2.FONT_HERSHEY_SIMPLEX, 2, (0,255,0), 2, cv2.LINE_4)
        x1, y1,w1,h1 = 0,0,175,75
        ## Draw black backgroun rectangle
        cv2.rectangle(frame, (x1,x1), (x1+w1-20, y1+h1-20), (0,0,0), -1)
        ## Add text
        cv2.putText(frame, 'Active', (x1 +int(w1/10), y1+int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255,0),2)
    else:
        counter = counter + 1
        status = 'Closed'

        cv2.rectangle(frame, (round(w/2) - 110,20), (round(w/2) + 110, 80), (38,38,38), -1)

        cv2.putText(frame, status, (round(w/2)-104,70), cv2.FONT_HERSHEY_SIMPLEX, 2, (0,0,255), 2, cv2.LINE_4)
        x1, y1,w1,h1 = 0,0,175,75
        ## Draw black backgroun rectangle
        cv2.rectangle(frame, (x1,x1), (x1+w1-20, y1+h1-20), (0,0,0), -1)
        ## Add text
        cv2.putText(frame, 'Active', (x1 +int(w1/10), y1+int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255,0),2)

        # if the counter is greater than 3, play and show alert that user is asleep
        if counter > 2:

            ## Draw black background rectangle
            cv2.rectangle(frame, (round(w/2) - 160, round(h) - 200), (round(w/2) + 160, round(h) - 120), (0,0,255), -1)
            cv2.putText(frame, 'DRIVER is not active', (round(w/2)-136,round(h) - 146), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 2, cv2.LINE_4)
            cv2.imshow('Drowsiness Detection', frame)
            k = cv2.waitKey(1)
            ## Sound
            playsound('rooster.mov')
            counter = 1
            continue
    
    cv2.imshow('Drowsiness Detection', frame)
    k = cv2.waitKey(1)
    if k == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-ace4968570d9> in <module>()
#      64 h = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
#      65 if not cap.isOpened():
# ---> 66     raise IOError('Cannot open webcam')
#      67
#      68 # set a counter
#
# OSError: Cannot open webcam
